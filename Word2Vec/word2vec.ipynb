# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

print("Step1")
filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  print("read_data")
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

print("Step1.1")
vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Step1
# Found and verified text8.zip
# Step1.1
# read_data
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [skip_window]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  293.726837158
# Nearest to i: mede, soriano, distilling, donnelly, tfl, lilac, shams, recursion,
# Nearest to while: packers, penny, slack, fadh, abhorrent, venter, cornet, zacharias,
# Nearest to this: irrealism, rossellini, preferences, taiwan, pataki, heavyweight, misuse, hebrides,
# Nearest to of: homepage, bonham, spur, corroborate, chulainn, banna, impeachment, ethnocentric,
# Nearest to during: juvenal, pipe, maury, abolished, effect, projecting, crickets, control,
# Nearest to not: dendrite, quantification, conservative, disarmament, knuth, galveston, workforce, gibraltar,
# Nearest to UNK: wildly, contour, theophoric, lakoff, moldovan, magen, monte, haul,
# Nearest to he: bosniaks, tomorrow, eliminated, milli, streaks, ward, tellers, dubrovnik,
# Nearest to can: riders, reich, colecovision, nei, paddling, intransitive, dever, denatured,
# Nearest to that: forgotten, valyria, torre, personas, darboux, standalone, atum, hora,
# Nearest to however: venomous, remoteness, playa, shaving, drivetrain, campbell, nilo, gelatin,
# Nearest to it: arbitrator, trams, latest, filing, denounce, anjouan, loser, chances,
# Nearest to use: memorable, loach, masturbate, death, elan, rewrote, nmr, egoism,
# Nearest to world: volcano, taklamakan, buber, simeon, affects, loti, hin, karenga,
# Nearest to at: kaye, eugenia, proportionate, prep, recording, dayan, sacraments, hangman,
# Nearest to about: guild, megalithic, vizier, aram, skits, omens, defy, doctor,
# Average loss at step  2000 :  113.578257178
# Average loss at step  4000 :  52.278230921
# Average loss at step  6000 :  33.0391588695
# Average loss at step  8000 :  23.8035478876
# Average loss at step  10000 :  18.0384578987
# Nearest to i: biscuit, underground, vs, abacus, intent, declared, plural, connects,
# Nearest to while: saw, steven, and, a, technologies, bckgr, columns, nature,
# Nearest to this: the, it, archie, alex, which, subproblems, agave, a,
# Nearest to of: and, in, homepage, raise, for, on, nine, weakness,
# Nearest to during: felt, effect, control, video, belgians, abolished, flow, iranian,
# Nearest to not: disarmament, allies, hunt, dendrite, transmutation, static, also, eek,
# Nearest to UNK: and, archie, alien, one, basins, fao, austin, vs,
# Nearest to he: it, achilles, they, ward, coke, remain, tomorrow, seven,
# Nearest to can: claims, riders, reich, anodes, giving, altenberg, archie, might,
# Nearest to that: forgotten, gb, var, aesthetic, think, and, ir, winnie,
# Nearest to however: campbell, tuna, venomous, true, erebus, kongo, six, in,
# Nearest to it: he, this, achilles, latest, eek, the, module, wait,
# Nearest to use: gland, death, commentary, nobel, memorable, grant, bang, ideas,
# Nearest to world: volcano, molinari, region, rivals, database, mathbf, agave, offensive,
# Nearest to at: of, recording, prep, for, in, moved, pda, nitride,
# Nearest to about: vizier, mya, guild, doctor, one, cincinnati, shell, react,
# Average loss at step  12000 :  14.1635758151
# Average loss at step  14000 :  11.9691606879
# Average loss at step  16000 :  9.92271349442
# Average loss at step  18000 :  8.29452151763
# Average loss at step  20000 :  8.08114784908
# Nearest to i: msg, dasyprocta, biscuit, abacus, underground, uther, establishments, vs,
# Nearest to while: penny, operatorname, andamans, crowley, dasyprocta, saw, columns, bckgr,
# Nearest to this: the, it, which, a, archie, operatorname, alex, circ,
# Nearest to of: and, in, for, dasyprocta, nine, operatorname, at, homepage,
# Nearest to during: dasyprocta, felt, of, video, iranian, fix, control, ezra,
# Nearest to not: to, circ, also, it, hunt, celeste, static, there,
# Nearest to UNK: operatorname, circ, agouti, dasyprocta, msg, archie, alien, and,
# Nearest to he: it, they, who, she, ward, seven, this, antoninus,
# Nearest to can: may, might, always, winners, onyx, seven, found, riders,
# Nearest to that: operatorname, dasyprocta, forgotten, and, andamanese, aurelian, gb, think,
# Nearest to however: campbell, venomous, tuna, operatorname, was, true, zoe, dasyprocta,
# Nearest to it: he, this, achilles, the, operatorname, which, latest, circ,
# Nearest to use: antoninus, death, gland, commentary, operatorname, dasyprocta, memorable, grant,
# Nearest to world: volcano, circ, agouti, molinari, rivals, suffragist, offensive, one,
# Nearest to at: in, of, for, dasyprocta, and, prep, recording, on,
# Nearest to about: vizier, mya, guild, one, agouti, shell, alphorn, cincinnati,
# Average loss at step  22000 :  7.15511176395
# Average loss at step  24000 :  6.89774848485
# Average loss at step  26000 :  6.68291872597
# Average loss at step  28000 :  6.47674134994
# Average loss at step  30000 :  5.94819040084
# Nearest to i: biscuit, dasyprocta, msg, waller, bcl, abakan, establishments, delegate,
# Nearest to while: penny, and, operatorname, mishnayot, dasyprocta, andamans, saw, packers,
# Nearest to this: it, the, which, a, archie, operatorname, that, circ,
# Nearest to of: and, in, for, dasyprocta, cpa, nine, operatorname, apologia,
# Nearest to during: of, in, clone, from, at, dasyprocta, and, arin,
# Nearest to not: to, also, it, they, circ, there, hunt, celeste,
# Nearest to UNK: operatorname, agouti, circ, dasyprocta, five, four, archie, seven,
# Nearest to he: it, they, she, who, ward, zero, motifs, yankee,
# Nearest to can: may, might, to, could, would, found, always, seven,
# Nearest to that: which, dasyprocta, operatorname, this, it, and, forgotten, gb,
# Nearest to however: campbell, playa, venomous, tuna, zoe, operatorname, true, dasyprocta,
# Nearest to it: he, this, which, azad, they, not, operatorname, achilles,
# Nearest to use: antoninus, death, gland, memorable, diphthongs, commentary, dasyprocta, operatorname,
# Nearest to world: volcano, circ, rivals, agouti, suffragist, molinari, bpp, first,
# Nearest to at: in, for, dasyprocta, and, prep, on, recording, with,
# Nearest to about: vizier, mya, guild, shell, alphorn, dasyprocta, omens, cincinnati,
# Average loss at step  32000 :  5.96364144123
# Average loss at step  34000 :  5.74839781201
# Average loss at step  36000 :  5.81689676368
# Average loss at step  38000 :  5.49631594896
# Average loss at step  40000 :  5.24078079343
# Nearest to i: biscuit, waller, msg, delegate, dasyprocta, it, bcl, underground,
# Nearest to while: when, andamans, among, saw, dasyprocta, operatorname, penny, mishnayot,
# Nearest to this: it, which, the, that, another, operatorname, a, archie,
# Nearest to of: recitative, in, zero, dasyprocta, and, operatorname, for, nine,
# Nearest to during: of, at, from, in, through, dasyprocta, after, clone,
# Nearest to not: it, also, they, to, circ, what, there, hunt,
# Nearest to UNK: operatorname, three, agouti, four, seven, dasyprocta, five, circ,
# Nearest to he: it, she, they, who, zero, ward, bosniaks, this,
# Nearest to can: may, could, would, might, will, to, should, must,
# Nearest to that: which, this, it, operatorname, dasyprocta, but, also, what,
# Nearest to however: campbell, playa, tuna, dasyprocta, operatorname, zoe, venomous, true,
# Nearest to it: he, this, which, azad, not, they, she, there,
# Nearest to use: death, antoninus, gland, memorable, dasyprocta, operatorname, commentary, diphthongs,
# Nearest to world: volcano, agouti, suffragist, circ, rivals, molinari, universality, region,
# Nearest to at: in, on, for, recitative, dasyprocta, from, during, prep,
# Nearest to about: vizier, mya, shell, alphorn, guild, dasyprocta, cincinnati, six,
# Average loss at step  42000 :  5.39147445226
# Average loss at step  44000 :  5.23380781996
# Average loss at step  46000 :  5.23320538414
# Average loss at step  48000 :  5.24932877076
# Average loss at step  50000 :  5.00889712811
# Nearest to i: biscuit, mede, he, dasyprocta, waller, msg, delegate, it,
# Nearest to while: when, and, operatorname, dasyprocta, although, saw, but, four,
# Nearest to this: it, which, the, that, another, operatorname, a, circ,
# Nearest to of: recitative, dasyprocta, in, for, and, cpa, operatorname, nine,
# Nearest to during: in, at, after, of, from, through, dasyprocta, and,
# Nearest to not: they, also, it, to, circ, usually, there, often,
# Nearest to UNK: operatorname, agouti, circ, dasyprocta, five, four, three, albury,
# Nearest to he: it, they, she, who, bosniaks, there, this, i,
# Nearest to can: may, could, would, will, might, must, should, to,
# Nearest to that: which, this, dasyprocta, operatorname, what, forgotten, it, and,
# Nearest to however: campbell, and, but, dasyprocta, operatorname, four, zoe, playa,
# Nearest to it: he, this, which, there, she, they, azad, aveiro,
# Nearest to use: death, antoninus, gland, dasyprocta, memorable, operatorname, altruistic, commentary,
# Nearest to world: volcano, agouti, circ, suffragist, rivals, molinari, first, conspicuously,
# Nearest to at: in, on, for, recitative, dasyprocta, during, recording, prep,
# Nearest to about: vizier, mya, shell, dasyprocta, alphorn, six, guild, seven,
# Average loss at step  52000 :  5.06223235059
# Average loss at step  54000 :  5.19175708914
# Average loss at step  56000 :  5.05701809096
# Average loss at step  58000 :  5.07564326346
# Average loss at step  60000 :  4.94999563158
# Nearest to i: biscuit, mede, he, dasyprocta, waller, msg, they, abakan,
# Nearest to while: when, although, but, dasyprocta, and, operatorname, among, ursus,
# Nearest to this: which, it, that, the, operatorname, circ, another, one,
# Nearest to of: recitative, and, dasyprocta, in, cpa, nine, pulau, for,
# Nearest to during: in, after, at, through, from, and, dasyprocta, of,
# Nearest to not: to, it, they, usually, also, often, circ, hunt,
# Nearest to UNK: michelob, operatorname, ursus, dasyprocta, pulau, circ, agouti, albury,
# Nearest to he: it, she, they, who, there, this, bosniaks, but,
# Nearest to can: may, would, could, will, might, must, should, cannot,
# Nearest to that: which, this, ursus, dasyprocta, operatorname, but, what, it,
# Nearest to however: but, campbell, ursus, when, dasyprocta, and, operatorname, zoe,
# Nearest to it: he, this, there, which, she, they, thibetanus, azad,
# Nearest to use: death, michelob, dasyprocta, antoninus, gland, operatorname, memorable, circ,
# Nearest to world: volcano, agouti, circ, molinari, suffragist, first, region, rivals,
# Nearest to at: in, on, recitative, dasyprocta, for, during, after, six,
# Nearest to about: mya, vizier, dasyprocta, shell, almighty, alphorn, agouti, five,
# Average loss at step  62000 :  4.98497254527
# Average loss at step  64000 :  4.8320026769
# Average loss at step  66000 :  4.59932534897
# Average loss at step  68000 :  4.98303735745
# Average loss at step  70000 :  4.90574126387
# Nearest to i: UNK, biscuit, mede, we, he, dasyprocta, waller, abakan,
# Nearest to while: when, although, but, dasyprocta, operatorname, among, and, saw,
# Nearest to this: which, it, the, that, another, circ, operatorname, there,
# Nearest to of: recitative, dasyprocta, and, cpa, pulau, for, operatorname, microbats,
# Nearest to during: after, at, in, through, cebus, under, dasyprocta, projecting,
# Nearest to not: usually, they, to, often, circ, also, it, be,
# Nearest to UNK: operatorname, michelob, ursus, dasyprocta, agouti, thaler, seven, three,
# Nearest to he: it, she, they, who, there, cebus, bosniaks, then,
# Nearest to can: may, would, could, will, might, must, should, cannot,
# Nearest to that: which, this, what, ursus, operatorname, dasyprocta, forgotten, where,
# Nearest to however: but, campbell, when, although, ursus, thaler, dasyprocta, zoe,
# Nearest to it: he, this, there, she, which, they, thibetanus, azad,
# Nearest to use: death, michelob, dasyprocta, antoninus, operatorname, gland, memorable, altruistic,
# Nearest to world: volcano, agouti, circ, rivals, molinari, grandeur, database, bubbles,
# Nearest to at: in, during, recitative, dasyprocta, on, after, for, recording,
# Nearest to about: mya, shell, vizier, dasyprocta, almighty, four, agouti, alphorn,
# Average loss at step  72000 :  4.75691751909
# Average loss at step  74000 :  4.8192062633
# Average loss at step  76000 :  4.73030867696
# Average loss at step  78000 :  4.8124959248
# Average loss at step  80000 :  4.79364560199
# Nearest to i: we, biscuit, UNK, mede, waller, dasyprocta, tsim, he,
# Nearest to while: when, although, but, among, dasyprocta, operatorname, though, saw,
# Nearest to this: which, it, that, the, another, circ, some, there,
# Nearest to of: dasyprocta, recitative, in, cpa, pulau, operatorname, and, ursus,
# Nearest to during: after, in, through, at, under, cebus, from, dasyprocta,
# Nearest to not: usually, they, often, it, to, be, also, circ,
# Nearest to UNK: operatorname, michelob, ursus, thaler, pulau, dasyprocta, circ, agouti,
# Nearest to he: it, she, they, who, there, cebus, bosniaks, i,
# Nearest to can: may, would, could, will, must, should, might, cannot,
# Nearest to that: which, this, what, ursus, dasyprocta, operatorname, however, microbats,
# Nearest to however: but, although, campbell, when, ursus, dasyprocta, thaler, where,
# Nearest to it: he, this, there, she, which, they, thibetanus, azad,
# Nearest to use: death, antoninus, dasyprocta, michelob, descendents, memorable, operatorname, gland,
# Nearest to world: volcano, toot, agouti, circ, grandeur, molinari, rivals, suffragist,
# Nearest to at: in, during, on, recitative, after, dasyprocta, colspan, pontificia,
# Nearest to about: mya, shell, four, dasyprocta, vizier, almighty, agouti, three,
# Average loss at step  82000 :  4.74811333954
# Average loss at step  84000 :  4.76639180279
# Average loss at step  86000 :  4.77311390114
# Average loss at step  88000 :  4.75153760958
# Average loss at step  90000 :  4.73243674606
# Nearest to i: we, biscuit, UNK, they, mede, he, tsim, t,
# Nearest to while: although, when, but, dasyprocta, operatorname, and, among, though,
# Nearest to this: which, it, the, that, another, some, circ, any,
# Nearest to of: recitative, dasyprocta, in, pulau, microbats, eight, cpa, and,
# Nearest to during: in, after, through, under, at, cebus, from, dasyprocta,
# Nearest to not: they, usually, often, now, be, it, circ, to,
# Nearest to UNK: operatorname, michelob, ursus, dasyprocta, circ, agouti, thaler, microcebus,
# Nearest to he: it, she, they, who, there, but, cebus, then,
# Nearest to can: may, would, will, could, must, should, might, cannot,
# Nearest to that: which, this, what, however, but, ursus, dasyprocta, operatorname,
# Nearest to however: but, although, ursus, when, campbell, dasyprocta, thaler, and,
# Nearest to it: he, this, there, she, which, they, thibetanus, azad,
# Nearest to use: dasyprocta, death, michelob, operatorname, antoninus, marek, selamat, kapoor,
# Nearest to world: toot, volcano, agouti, molinari, grandeur, exact, circ, region,
# Nearest to at: in, during, recitative, dasyprocta, after, on, for, six,
# Nearest to about: mya, shell, dasyprocta, dreidel, almighty, tabula, vizier, agouti,
# Average loss at step  92000 :  4.66897313142
# Average loss at step  94000 :  4.74137316811
# Average loss at step  96000 :  4.68863942802
# Average loss at step  98000 :  4.59168099242
# Average loss at step  100000 :  4.69862684011
# Nearest to i: we, biscuit, you, they, tsim, he, mede, t,
# Nearest to while: although, but, when, though, operatorname, dasyprocta, however, among,
# Nearest to this: which, it, the, that, another, some, circ, thibetanus,
# Nearest to of: recitative, stenella, in, dasyprocta, eight, pulau, and, operatorname,
# Nearest to during: after, in, through, under, at, cebus, with, dasyprocta,
# Nearest to not: usually, often, they, now, also, to, circ, be,
# Nearest to UNK: operatorname, michelob, ursus, agouti, dasyprocta, microcebus, pulau, thaler,
# Nearest to he: it, she, they, who, there, cebus, but, i,
# Nearest to can: may, would, could, will, must, should, might, cannot,
# Nearest to that: which, however, what, this, but, ursus, dasyprocta, operatorname,
# Nearest to however: but, although, when, ursus, that, campbell, dasyprocta, thaler,
# Nearest to it: he, this, there, she, which, they, thibetanus, circ,
# Nearest to use: dasyprocta, operatorname, antoninus, michelob, death, marek, selamat, thaler,
# Nearest to world: toot, volcano, agouti, grandeur, molinari, busan, exact, circ,
# Nearest to at: in, during, recitative, dasyprocta, on, after, colspan, pontificia,
# Nearest to about: shell, mya, dasyprocta, tabula, dreidel, almighty, proponent, alhazen,

# %%
# Step 6: Visualize the embeddings.


def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
